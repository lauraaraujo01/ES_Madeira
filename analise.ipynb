# %%
import pandas as pd

# %%
df = pd.read_csv("Madeira-Moodle-1.1.csv", sep=";")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35045 entries, 0 to 35044
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OBJECTID      35045 non-null  int64
#  1   PAR_ID        35045 non-null  float64
#  2   PAR_NUM       35045 non-null  object
#  3   Shape_Length  35045 non-null  float64
#  4   Shape_Area    35045 non-null  float64
#  5   geometry      35045 non-null  object
#  6   OWNER         35045 non-null  int64
#  7   Freguesia     18743 non-null  object
#  8   Municipio     18743 non-null  object
#  9   Ilha          18743 non-null  object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 2.7+ MB

# %%
df.head(10)
#Mostra as 10 primeiras linhas do dataframe
# Out:
#    OBJECTID      PAR_ID      PAR_NUM  Shape_Length   Shape_Area  \
# 0         1   7343148.0  2,99624E+12     57.246934   202.059814
# 1         2   7344660.0  2,99622E+12     55.638007   151.763875
# 2         3   7344925.0  2,98623E+12     39.693449    87.832910
# 3         4   7344935.0  2,98623E+12    120.672910   318.417973
# 4         5  20461144.0  2,99624E+12    159.823842  1240.830769
# 5         6   9345796.0  2,98622E+12    119.364832   670.688524
# 6         7   7350748.0  2,98622E+12    225.200733  1812.934032
# 7         8   7351255.0  2,97622E+12    102.306104   415.370905
# 8         9   7351622.0  2,98621E+12     74.457391   289.180022
# 9        10   9466621.0   2,9962E+12    137.075158   931.512426
#
#                                             geometry  OWNER        Freguesia  \
# 0  MULTIPOLYGON (((299218.5203999998 3623637.4791...     93  Arco da Calheta
# 1  MULTIPOLYGON (((298724.1991999997 3623192.6094...     68  Arco da Calheta
# ...
